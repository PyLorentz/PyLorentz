# %% [markdown]
# ## visualizations testing

# %%
from PyLorentz.utils.magnetizations import bloch, blochII, neel, hopfion, hopfion_cylinder, lillihook
from PyLorentz.visualize.vector_show import show_2D, show_3D
import colorcet as cc

# %%
# update show3d
# - a stuff

# %%
dim = 128
# mag_z, mag_y, mag_x = neel(dim, 'oi')
# show_2D(mag_y, mag_x, num_arrows=20, arrow_size=10, arrow_width=1, cmap="c10")

mag_z, mag_y, mag_x = hopfion(dim)
show_2D(mag_y, mag_x, mag_z, num_arrows=20, arrow_width=1, arrow_size = 0.5, cmap="c10")
show_3D(mag_z, mag_y, mag_x)
# Out:
# Summing along first axis
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
